# %%
import  numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
img=cv2.imread("CVfiles/water_coins.jpg")
plt.imshow(img)

# %%
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
ret, thresh = cv2.threshold(gray,0,255,cv2.THRESH_BINARY_INV+cv2.THRESH_OTSU)
plt.imshow((np.hstack([gray,thresh])))
# Out:
# [[234 239 242 ...   0   0   0]
#  [234 239 242 ...   0   0   0]
#  [234 239 242 ...   0   0   0]
#  ...
#  [212 231 232 ...   0   0   0]
#  [206 225 227 ...   0   0   0]
#  [200 219 222 ...   0   0   0]]
